# %% [markdown]
# <a href="https://colab.research.google.com/github/Saturn-space/Python-Development/blob/main/011.%20Python%20Exception%20Handling%20(05_03_26).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num1 = int(input("Enter a number : "))
  num2 = int(input("Enter a number : "))
  result = num1/num2;

  print(result)

except ValueError:
  print("Please Enter the values correctly")

except ZeroDivisionError:
  print("Division By zero not allowed")

except TypeError:        # only used when dealing with multiple types of data like adding charater and int value together.
  print("Wrong type of values")

finally:
  print("Program Executed Successfully !")
# Out:
# Enter a number : 6.78
# Please Enter the values correctly
# Program Executed Successfully !

# %%
try:
  val1 = int(input("Enter a value : "))
  val2 = input("Enter a value : ")

  result = val1 + val2
  print("Result :",result)

except ValueError:
  print("Wrong values")

except TypeError:
  print("Different type of value")

finally:
  print("Program Completed")
# Out:
# Enter a value : i am a man
# Enter a value : iof character
# Result : i am a maniof character
# Program Completed

# %%
try:
  v1 = int(input("Enter a value : "))
  v2 = int(input("Enter another value : "))

raise Done("Noting happen !")

finally:
  print("Perfectly Done")
# Out:
#   File "/tmp/ipykernel_892/4154288493.py", line 5
#     raise Done("Noting happen !")
#     ^
# SyntaxError: expected 'except' or 'finally' block
